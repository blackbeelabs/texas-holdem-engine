# %%
from engine.single_game import SingleGame, PlayerAction, Player
import random

def simulate_games(num_games: int = 5):
    """Simulate multiple poker games with random player actions"""
    
    # Create a pool of players
    players = [
        Player("Alice", 1000),
        Player("Bob", 1000),
        Player("Charlie", 1000),
        Player("David", 1000)
    ]
    
    for game_num in range(num_games):
        print(f"\n=== Starting Game {game_num + 1} ===")
        
        # Reset players for new game
        for player in players:
            player.clear_hand()
            player.is_active = True
        
        # Initialize game
        game = SingleGame(players=players)
        
        # Initial setup
        game.post_blinds()
        game.deal_hole_cards()
        
        # Simulate betting rounds
        betting_rounds = ['PREFLOP', 'FLOP', 'TURN', 'RIVER']
        
        for round_name in betting_rounds:
            print(f"\n--- {round_name} Round ---")
            
            # Deal community cards if not preflop
            if round_name != 'PREFLOP':
                game.advance_betting_round()
                game.deal_community_cards()
            
            # Simulate betting for each player
            for i, player in enumerate(players):
                if not player.is_active:
                    continue
                
                # Randomly choose an action
                action = random.choices(
                    [PlayerAction.FOLD, PlayerAction.CALL, PlayerAction.RAISE],
                    weights=[0.2, 0.5, 0.3]
                )[0]
                
                # Determine bet amount for calls and raises
                current_bet = max([bet.amount for bet in game.bets]) if game.bets else 0
                if action == PlayerAction.CALL:
                    amount = current_bet
                elif action == PlayerAction.RAISE:
                    amount = current_bet + random.randint(20, 100)
                else:
                    amount = 0
                
                # Process the action
                game.process_player_action(i, action, amount)
                print(f"{player.name} decides to {action.value}" + 
                      (f" ${amount}" if amount > 0 else ""))
            
            # Print game state after each round
            game.print_current_state()
            
            # Check if only one player remains active
            active_players = [p for p in players if p.is_active]
            if len(active_players) == 1:
                print(f"\n{active_players[0].name} wins ${game.get_pot()}!")
                break

if __name__ == "__main__":
    simulate_games(3)
# Out:
# === Starting Game 1 ===
# Dealt hole cards to 4 players
#
# --- PREFLOP Round ---
# Alice decides to raise $59
# Bob decides to raise $131
# Charlie decides to call $131
# David decides to raise $180
# Current betting round: BettingRound.PREFLOP
# Players:
#   Alice (active): Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6), Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
#   Bob (active): Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7), Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
#   Charlie (active): Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12), Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
#   David (active): Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9), Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Community cards:
#   (No community cards)
# Deck:
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 59
#   Bob: 131
#   Charlie: 131
#   David: 180
# Pot: 531
#
# --- FLOP Round ---
# Betting round advancing from preflop to flop.
# Alice decides to call $180
# Bob decides to call $180
# Charlie decides to call $180
# David decides to call $180
# Current betting round: BettingRound.FLOP
# Players:
#   Alice (active): Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6), Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
#   Bob (active): Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7), Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
#   Charlie (active): Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12), Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
#   David (active): Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9), Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Community cards:
#   Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
#   Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Deck:
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 59
#   Bob: 131
#   Charlie: 131
#   David: 180
#   Alice: 180
#   Bob: 180
#   Charlie: 180
#   David: 180
# Pot: 1251
#
# --- TURN Round ---
# Betting round advancing from flop to turn.
# Alice decides to fold
# Bob decides to fold
# Charlie decides to call $180
# David decides to raise $236
# Current betting round: BettingRound.TURN
# Players:
#   Alice (inactive): Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6), Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
#   Bob (inactive): Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7), Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
#   Charlie (active): Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12), Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
#   David (active): Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9), Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Community cards:
#   Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
#   Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
#   Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Deck:
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 59
#   Bob: 131
#   Charlie: 131
#   David: 180
#   Alice: 180
#   Bob: 180
#   Charlie: 180
#   David: 180
#   Charlie: 180
#   David: 236
# Pot: 1667
#
# --- RIVER Round ---
# Betting round advancing from turn to river.
# Charlie decides to raise $306
# David decides to fold
# Current betting round: BettingRound.RIVER
# Players:
#   Alice (inactive): Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6), Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
#   Bob (inactive): Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7), Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
#   Charlie (active): Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12), Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
#   David (inactive): Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9), Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Community cards:
#   Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
#   Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
#   Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
#   Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Deck:
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 59
#   Bob: 131
#   Charlie: 131
#   David: 180
#   Alice: 180
#   Bob: 180
#   Charlie: 180
#   David: 180
#   Charlie: 180
#   David: 236
#   Charlie: 306
# Pot: 1973
#
# Charlie wins $1973!
#
# === Starting Game 2 ===
# Dealt hole cards to 4 players
#
# --- PREFLOP Round ---
# Alice decides to call $20
# Bob decides to call $20
# Charlie decides to call $20
# David decides to raise $77
# Current betting round: BettingRound.PREFLOP
# Players:
#   Alice (active): Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9), Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
#   Bob (active): Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10), Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
#   Charlie (active): Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (active): Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8), Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Community cards:
#   (No community cards)
# Deck:
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
# Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 20
#   Bob: 20
#   Charlie: 20
#   David: 77
# Pot: 167
#
# --- FLOP Round ---
# Betting round advancing from preflop to flop.
# Alice decides to raise $121
# Bob decides to raise $177
# Charlie decides to call $177
# David decides to fold
# Current betting round: BettingRound.FLOP
# Players:
#   Alice (active): Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9), Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
#   Bob (active): Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10), Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
#   Charlie (active): Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (inactive): Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8), Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Community cards:
#   Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
#   Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
#   Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Deck:
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 20
#   Bob: 20
#   Charlie: 20
#   David: 77
#   Alice: 121
#   Bob: 177
#   Charlie: 177
# Pot: 642
#
# --- TURN Round ---
# Betting round advancing from flop to turn.
# Alice decides to raise $269
# Bob decides to fold
# Charlie decides to fold
# Current betting round: BettingRound.TURN
# Players:
#   Alice (active): Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9), Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
#   Bob (inactive): Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10), Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
#   Charlie (inactive): Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (inactive): Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8), Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Community cards:
#   Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
#   Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13)
#   Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
#   Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
# Deck:
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 20
#   Bob: 20
#   Charlie: 20
#   David: 77
#   Alice: 121
#   Bob: 177
#   Charlie: 177
#   Alice: 269
# Pot: 911
#
# Alice wins $911!
#
# === Starting Game 3 ===
# Dealt hole cards to 4 players
#
# --- PREFLOP Round ---
# Alice decides to raise $57
# Bob decides to raise $96
# Charlie decides to call $96
# David decides to raise $155
# Current betting round: BettingRound.PREFLOP
# Players:
#   Alice (active): Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2), Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Bob (active): Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12), Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
#   Charlie (active): Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (active): Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13), Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Community cards:
#   (No community cards)
# Deck:
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
# Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
# Card(rank=K, suit=Clubs, card_name=K-Clubs, rank_value=13)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 57
#   Bob: 96
#   Charlie: 96
#   David: 155
# Pot: 434
#
# --- FLOP Round ---
# Betting round advancing from preflop to flop.
# Alice decides to call $155
# Bob decides to raise $186
# Charlie decides to raise $247
# David decides to call $247
# Current betting round: BettingRound.FLOP
# Players:
#   Alice (active): Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2), Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Bob (active): Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12), Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
#   Charlie (active): Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (active): Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13), Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Community cards:
#   Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
#   Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
#   Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
# Deck:
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Card(rank=10, suit=Hearts, card_name=10-Hearts, rank_value=10)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 57
#   Bob: 96
#   Charlie: 96
#   David: 155
#   Alice: 155
#   Bob: 186
#   Charlie: 247
#   David: 247
# Pot: 1269
#
# --- TURN Round ---
# Betting round advancing from flop to turn.
# Alice decides to call $247
# Bob decides to raise $338
# Charlie decides to fold
# David decides to call $338
# Current betting round: BettingRound.TURN
# Players:
#   Alice (active): Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2), Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Bob (active): Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12), Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
#   Charlie (inactive): Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (active): Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13), Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Community cards:
#   Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
#   Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
#   Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
#   Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
# Deck:
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
# Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Card(rank=6, suit=Hearts, card_name=6-Hearts, rank_value=6)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 57
#   Bob: 96
#   Charlie: 96
#   David: 155
#   Alice: 155
#   Bob: 186
#   Charlie: 247
#   David: 247
#   Alice: 247
#   Bob: 338
#   David: 338
# Pot: 2192
#
# --- RIVER Round ---
# Betting round advancing from turn to river.
# Alice decides to call $338
# Bob decides to call $338
# David decides to fold
# Current betting round: BettingRound.RIVER
# Players:
#   Alice (active): Card(rank=2, suit=Spades, card_name=2-Spades, rank_value=2), Card(rank=7, suit=Hearts, card_name=7-Hearts, rank_value=7)
#   Bob (active): Card(rank=Q, suit=Hearts, card_name=Q-Hearts, rank_value=12), Card(rank=A, suit=Clubs, card_name=A-Clubs, rank_value=14)
#   Charlie (inactive): Card(rank=8, suit=Diamonds, card_name=8-Diamonds, rank_value=8), Card(rank=8, suit=Hearts, card_name=8-Hearts, rank_value=8)
#   David (inactive): Card(rank=K, suit=Spades, card_name=K-Spades, rank_value=13), Card(rank=A, suit=Diamonds, card_name=A-Diamonds, rank_value=14)
# Community cards:
#   Card(rank=K, suit=Hearts, card_name=K-Hearts, rank_value=13)
#   Card(rank=4, suit=Spades, card_name=4-Spades, rank_value=4)
#   Card(rank=4, suit=Diamonds, card_name=4-Diamonds, rank_value=4)
#   Card(rank=J, suit=Hearts, card_name=J-Hearts, rank_value=11)
#   Card(rank=10, suit=Diamonds, card_name=10-Diamonds, rank_value=10)
# Deck:
# Card(rank=2, suit=Clubs, card_name=2-Clubs, rank_value=2)
# Card(rank=2, suit=Diamonds, card_name=2-Diamonds, rank_value=2)
# Card(rank=A, suit=Spades, card_name=A-Spades, rank_value=14)
# Card(rank=5, suit=Clubs, card_name=5-Clubs, rank_value=5)
# Card(rank=9, suit=Diamonds, card_name=9-Diamonds, rank_value=9)
# Card(rank=5, suit=Hearts, card_name=5-Hearts, rank_value=5)
# Card(rank=Q, suit=Clubs, card_name=Q-Clubs, rank_value=12)
# Card(rank=J, suit=Diamonds, card_name=J-Diamonds, rank_value=11)
# Card(rank=4, suit=Clubs, card_name=4-Clubs, rank_value=4)
# Card(rank=7, suit=Diamonds, card_name=7-Diamonds, rank_value=7)
# Card(rank=Q, suit=Diamonds, card_name=Q-Diamonds, rank_value=12)
# Card(rank=5, suit=Diamonds, card_name=5-Diamonds, rank_value=5)
# Card(rank=Q, suit=Spades, card_name=Q-Spades, rank_value=12)
# Card(rank=6, suit=Diamonds, card_name=6-Diamonds, rank_value=6)
# Card(rank=9, suit=Clubs, card_name=9-Clubs, rank_value=9)
# Card(rank=3, suit=Hearts, card_name=3-Hearts, rank_value=3)
# Card(rank=3, suit=Spades, card_name=3-Spades, rank_value=3)
# Card(rank=3, suit=Clubs, card_name=3-Clubs, rank_value=3)
# Card(rank=J, suit=Clubs, card_name=J-Clubs, rank_value=11)
# Card(rank=9, suit=Spades, card_name=9-Spades, rank_value=9)
# Card(rank=10, suit=Spades, card_name=10-Spades, rank_value=10)
# Card(rank=6, suit=Clubs, card_name=6-Clubs, rank_value=6)
# Card(rank=8, suit=Clubs, card_name=8-Clubs, rank_value=8)
# Card(rank=7, suit=Spades, card_name=7-Spades, rank_value=7)
# Card(rank=6, suit=Spades, card_name=6-Spades, rank_value=6)
# Card(rank=2, suit=Hearts, card_name=2-Hearts, rank_value=2)
# Card(rank=4, suit=Hearts, card_name=4-Hearts, rank_value=4)
# Card(rank=3, suit=Diamonds, card_name=3-Diamonds, rank_value=3)
# Card(rank=K, suit=Diamonds, card_name=K-Diamonds, rank_value=13)
# Card(rank=A, suit=Hearts, card_name=A-Hearts, rank_value=14)
# Card(rank=7, suit=Clubs, card_name=7-Clubs, rank_value=7)
# Card(rank=9, suit=Hearts, card_name=9-Hearts, rank_value=9)
# Card(rank=J, suit=Spades, card_name=J-Spades, rank_value=11)
# Card(rank=10, suit=Clubs, card_name=10-Clubs, rank_value=10)
# Card(rank=5, suit=Spades, card_name=5-Spades, rank_value=5)
# Card(rank=8, suit=Spades, card_name=8-Spades, rank_value=8)
# Bets:
#   Alice: 10
#   Bob: 20
#   Alice: 57
#   Bob: 96
#   Charlie: 96
#   David: 155
#   Alice: 155
#   Bob: 186
#   Charlie: 247
#   David: 247
#   Alice: 247
#   Bob: 338
#   David: 338
#   Alice: 338
#   Bob: 338
# Pot: 2868
